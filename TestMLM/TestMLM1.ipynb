# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
# Create the data
data = {
    'Age': [25, 30, 45, 22, 50],
    'Income': [40000.50, 55000.75, 90000.00, 30000.25, 110000.00],
    'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Los Angeles'],
    'Purchased': [0, 1, 1, 0, 1]  # Target variable (0 or 1)
}

# Create the DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#    Age     Income         City  Purchased
# 0   25   40000.50     New York          0
# 1   30   55000.75  Los Angeles          1
# 2   45   90000.00      Chicago          1
# 3   22   30000.25     New York          0
# 4   50  110000.00  Los Angeles          1

# %%
X = data['Income']
y = data['Purchased']
